# %%
from evaluator import *
from leaf_classification import ImageRecognition
from sklearn import metrics
import tensorflow as tf
import matplotlib.pyplot as plt
import random
import math
import scipy
from scipy import ndimage
# %matplotlib inline

# %%
ir = ImageRecognition()
ir.load_processed_data('data_no_id_100.pkl')
# ir.load_processed_data('data_csv_only.pkl')

# %%
def plotImages(units):
    filters = units.shape[0]
    plt.figure(1, figsize=(10,10))
    n_columns = 6
    n_rows = math.ceil(filters / n_columns) + 1
    for i in range(filters):
        plt.subplot(n_rows, n_columns, i+1)
        plt.title('Filter ' + str(i))
        plt.imshow(units[i,:,:], interpolation="nearest", cmap="gray")

# %%
ir.data[0].shape
pic = ir.data[0:3,:10000]
pic = np.reshape(pic, [3, 100,100,1])

# %%
plotImages(pic)
# Out:
# 1.0.0

# %%
# rotated_pic = tf.contrib.image.rotate(pic, random.uniform(0,6.28))
pic2 = tf.placeholder(tf.float32, [None,100,100, 1])
rotated_pic = tf.contrib.image.rotate(pic2, 200)
sess = tf.Session()
output = sess.run(rotated_pic, feed_dict={pic2:pic})
# plt.imshow(output, cmap="gray")
output = np.reshape(output, [3,100,100])
print output.shape
plotImages(output)
# Out:
# (3, 100, 100)

# %%
print pic.shape
from random import randint
degree = randint(0,3) * 90 + randint(-15,15)
print degree
out = scipy.ndimage.rotate(pic, degree, axes=(1,2), order=0)
# out = scipy.ndimage.rotate(pic, 105, axes=(1,2), order=0)
plotImages(out)
np.max(out)
# Out:
# (3, 100, 100, 1)
# -10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-224-f5c46b8aa437> in <module>()
#       5 out = scipy.ndimage.rotate(pic, degree, axes=(1,2), order=0)
#       6 # out = scipy.ndimage.rotate(pic, 105, axes=(1,2), order=0)
# ----> 7 plotImages(out)
#       8 np.max(out)
#
# <ipython-input-94-b6b851314a96> in plotImages(units)
#       7         plt.subplot(n_rows, n_columns, i+1)
#       8         plt.title('Filter ' + str(i))
# ----> 9         plt.imshow(units[i,:,:], interpolation="nearest", cmap="gray")
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3156                         filternorm=filternorm, filterrad=filterrad,
#    3157                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3158                         **kwargs)
#    3159     finally:
#    3160         ax._hold = washold
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
#    1891                                   RuntimeWarning, stacklevel=2)
# -> 1892             return func(ax, *args, **kwargs)
#    1893         pre_doc = inner.__doc__
#    1894         if pre_doc is None:
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_axes.pyc in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5116                               resample=resample, **kwargs)
#    5117
# -> 5118         im.set_data(X)
#    5119         im.set_alpha(alpha)
#    5120         if im.get_clip_path() is None:
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/image.pyc in set_data(self, A)
#     547         if (self._A.ndim not in (2, 3) or
#     548                 (self._A.ndim == 3 and self._A.shape[-1] not in (3, 4))):
# --> 549             raise TypeError("Invalid dimensions for image data")
#     550
#     551         self._imcache = None
#
# TypeError: Invalid dimensions for image data

# %%
from scipy import misc
misc.imrotate(pic, )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-151-49460b908b91> in <module>()
#       1 from PIL import Image
# ----> 2 Image.fromarray(pic)
#
# /usr/lib/python2.7/dist-packages/PIL/Image.pyc in fromarray(obj, mode)
#    2151         except KeyError:
#    2152             # print typekey
# -> 2153             raise TypeError("Cannot handle this data type")
#    2154     else:
#    2155         rawmode = mode
#
# TypeError: Cannot handle this data type

# %%
run_name = '02-20-2017_05:18:32'
#run_name = 'mlp_02-20-2017_06:09:32'
names, train_index, test_index = load_metadata('metadata_' + run_name + '.pkl')

# %%
#tmp = ir.data[test_index[0]]
#test = tmp[:,:-99]
#label = tmp[:, -99:]
test = ir.data[:,:-99]
label = ir.data[:,-99:]
print test.shape
print label.shape
metadata = dict(
    test=test,
    test_labels=label,
    id=ir.identifier,
    one_hot_names=ir.one_hot_names,
    n_input=ir.n_input,
    model_location="model/model_" + run_name + "-999",
    tensor_name="output/activation:0",
    input_x_tensor_name="input_1/x-input:0",
    input_y_tensor_name="input_1/y-input:0",
    save_dir="predictions/",
    save_name="model_" + run_name + ".pkl",
    learning_rate=0.01)
# Out:
# (990, 192)
# (990, 99)

# %%
load_session_and_save_prediction(**metadata)

# %%
pred = load_predictions(metadata['save_dir'] + metadata['save_name'])
best_guess_index, actual_index, correct_predictions, correct_percentage = compare_with_true(pred, (metadata['test_labels']))
print sklearn.metrics.classification_report(actual_index, best_guess_index,target_names=metadata['one_hot_names'])
# Out:
#                               precision    recall  f1-score   support
#
#              Acer_Capillipes       1.00      1.00      1.00        10
#              Acer_Circinatum       1.00      1.00      1.00        10
#                    Acer_Mono       1.00      1.00      1.00        10
#                  Acer_Opalus       0.91      1.00      0.95        10
#                Acer_Palmatum       1.00      1.00      1.00        10
#                  Acer_Pictum       1.00      1.00      1.00        10
#              Acer_Platanoids       1.00      1.00      1.00        10
#                  Acer_Rubrum       1.00      1.00      1.00        10
#               Acer_Rufinerve       1.00      1.00      1.00        10
#             Acer_Saccharinum       1.00      1.00      1.00        10
#                Alnus_Cordata       1.00      1.00      1.00        10
#           Alnus_Maximowiczii       1.00      1.00      1.00        10
#                  Alnus_Rubra       1.00      1.00      1.00        10
#            Alnus_Sieboldiana       1.00      1.00      1.00        10
#                Alnus_Viridis       1.00      1.00      1.00        10
#          Arundinaria_Simonii       1.00      0.90      0.95        10
#        Betula_Austrosinensis       1.00      1.00      1.00        10
#               Betula_Pendula       1.00      1.00      1.00        10
#         Callicarpa_Bodinieri       1.00      1.00      1.00        10
#              Castanea_Sativa       1.00      1.00      1.00        10
#            Celtis_Koraiensis       1.00      1.00      1.00        10
#          Cercis_Siliquastrum       1.00      1.00      1.00        10
#             Cornus_Chinensis       1.00      1.00      1.00        10
#           Cornus_Controversa       1.00      1.00      1.00        10
#           Cornus_Macrophylla       1.00      1.00      1.00        10
#            Cotinus_Coggygria       1.00      1.00      1.00        10
#           Crataegus_Monogyna       1.00      0.90      0.95        10
#          Cytisus_Battandieri       1.00      1.00      1.00        10
#       Eucalyptus_Glaucescens       0.91      1.00      0.95        10
#          Eucalyptus_Neglecta       1.00      1.00      1.00        10
#          Eucalyptus_Urnigera       1.00      1.00      1.00        10
#              Fagus_Sylvatica       1.00      1.00      1.00        10
#                Ginkgo_Biloba       1.00      1.00      1.00        10
#              Ilex_Aquifolium       1.00      1.00      1.00        10
#                 Ilex_Cornuta       1.00      1.00      1.00        10
#      Liquidambar_Styraciflua       1.00      1.00      1.00        10
#      Liriodendron_Tulipifera       1.00      1.00      1.00        10
#    Lithocarpus_Cleistocarpus       0.62      1.00      0.77        10
#           Lithocarpus_Edulis       1.00      0.40      0.57        10
#           Magnolia_Heptapeta       1.00      1.00      1.00        10
#         Magnolia_Salicifolia       1.00      1.00      1.00        10
#                  Morus_Nigra       0.91      1.00      0.95        10
#                Olea_Europaea       1.00      1.00      1.00        10
#                  Phildelphus       1.00      1.00      1.00        10
#            Populus_Adenopoda       1.00      1.00      1.00        10
#        Populus_Grandidentata       1.00      1.00      1.00        10
#                Populus_Nigra       1.00      1.00      1.00        10
#                 Prunus_Avium       1.00      1.00      1.00        10
#            Prunus_X_Shmittii       1.00      0.90      0.95        10
#        Pterocarya_Stenoptera       1.00      1.00      1.00        10
#               Quercus_Afares       1.00      1.00      1.00        10
#            Quercus_Agrifolia       1.00      1.00      1.00        10
#            Quercus_Alnifolia       1.00      1.00      1.00        10
#              Quercus_Brantii       1.00      1.00      1.00        10
#          Quercus_Canariensis       1.00      1.00      1.00        10
#        Quercus_Castaneifolia       1.00      1.00      1.00        10
#               Quercus_Cerris       1.00      1.00      1.00        10
#          Quercus_Chrysolepis       1.00      1.00      1.00        10
#            Quercus_Coccifera       1.00      1.00      1.00        10
#             Quercus_Coccinea       1.00      1.00      1.00        10
#          Quercus_Crassifolia       1.00      1.00      1.00        10
#            Quercus_Crassipes       1.00      1.00      1.00        10
#         Quercus_Dolicholepis       1.00      1.00      1.00        10
#        Quercus_Ellipsoidalis       1.00      1.00      1.00        10
#              Quercus_Greggii       1.00      1.00      1.00        10
#         Quercus_Hartwissiana       1.00      1.00      1.00        10
#                 Quercus_Ilex       1.00      1.00      1.00        10
#           Quercus_Imbricaria       1.00      1.00      1.00        10
#       Quercus_Infectoria_sub       1.00      1.00      1.00        10
#             Quercus_Kewensis       1.00      1.00      1.00        10
#                Quercus_Nigra       1.00      1.00      1.00        10
#            Quercus_Palustris       1.00      1.00      1.00        10
#              Quercus_Phellos       1.00      1.00      1.00        10
#       Quercus_Phillyraeoides       1.00      1.00      1.00        10
#              Quercus_Pontica       1.00      1.00      1.00        10
#            Quercus_Pubescens       1.00      1.00      1.00        10
#            Quercus_Pyrenaica       1.00      1.00      1.00        10
#          Quercus_Rhysophylla       1.00      1.00      1.00        10
#                Quercus_Rubra       1.00      1.00      1.00        10
#       Quercus_Semecarpifolia       1.00      1.00      1.00        10
#            Quercus_Shumardii       1.00      1.00      1.00        10
#                Quercus_Suber       1.00      1.00      1.00        10
#               Quercus_Texana       1.00      1.00      1.00        10
#              Quercus_Trojana       1.00      1.00      1.00        10
#           Quercus_Variabilis       1.00      1.00      1.00        10
#            Quercus_Vulcanica       1.00      1.00      1.00        10
#          Quercus_x_Hispanica       1.00      1.00      1.00        10
#            Quercus_x_Turneri       1.00      1.00      1.00        10
#  Rhododendron_x_Russellianum       1.00      1.00      1.00        10
#               Salix_Fragilis       1.00      1.00      1.00        10
#               Salix_Intergra       1.00      1.00      1.00        10
#                  Sorbus_Aria       1.00      1.00      1.00        10
#                Tilia_Oliveri       1.00      1.00      1.00        10
#           Tilia_Platyphyllos       1.00      1.00      1.00        10
#              Tilia_Tomentosa       1.00      1.00      1.00        10
#           Ulmus_Bergmanniana       1.00      1.00      1.00        10
#               Viburnum_Tinus       1.00      1.00      1.00        10
# Viburnum_x_Rhytidophylloides       1.00      1.00      1.00        10
#              Zelkova_Serrata       1.00      1.00      1.00        10
#
#                  avg / total       0.99      0.99      0.99       990

# %%
pred = load_predictions(metadata['save_dir'] + metadata['save_name'])
best_guess_index, actual_index, correct_predictions, correct_percentage = compare_with_true(pred[test_index[0]], (metadata['test_labels'])[test_index[0]])
print sklearn.metrics.classification_report(actual_index, best_guess_index,target_names=metadata['one_hot_names'])
#print sklearn.metrics.classification_report(best_guess_index, actual_index, target_names=metadata['one_hot_names'])
# Out:
#                               precision    recall  f1-score   support
#
#              Acer_Capillipes       1.00      1.00      1.00         1
#              Acer_Circinatum       1.00      1.00      1.00         1
#                    Acer_Mono       1.00      1.00      1.00         1
#                  Acer_Opalus       1.00      1.00      1.00         2
#                Acer_Palmatum       1.00      1.00      1.00         1
#                  Acer_Pictum       1.00      1.00      1.00         2
#              Acer_Platanoids       1.00      1.00      1.00         1
#                  Acer_Rubrum       1.00      1.00      1.00         1
#               Acer_Rufinerve       1.00      1.00      1.00         1
#             Acer_Saccharinum       1.00      1.00      1.00         1
#                Alnus_Cordata       1.00      1.00      1.00         1
#           Alnus_Maximowiczii       1.00      1.00      1.00         2
#                  Alnus_Rubra       1.00      1.00      1.00         2
#            Alnus_Sieboldiana       1.00      1.00      1.00         1
#                Alnus_Viridis       1.00      1.00      1.00         1
#          Arundinaria_Simonii       1.00      1.00      1.00         1
#        Betula_Austrosinensis       1.00      1.00      1.00         2
#               Betula_Pendula       1.00      1.00      1.00         1
#         Callicarpa_Bodinieri       0.50      1.00      0.67         1
#              Castanea_Sativa       0.67      1.00      0.80         2
#            Celtis_Koraiensis       1.00      1.00      1.00         1
#          Cercis_Siliquastrum       1.00      1.00      1.00         2
#             Cornus_Chinensis       1.00      1.00      1.00         1
#           Cornus_Controversa       1.00      1.00      1.00         1
#           Cornus_Macrophylla       1.00      0.50      0.67         2
#            Cotinus_Coggygria       1.00      1.00      1.00         3
#           Crataegus_Monogyna       1.00      0.50      0.67         2
#          Cytisus_Battandieri       0.00      0.00      0.00         0
#       Eucalyptus_Glaucescens       0.00      0.00      0.00         1
#          Eucalyptus_Neglecta       1.00      1.00      1.00         1
#          Eucalyptus_Urnigera       1.00      1.00      1.00         1
#              Fagus_Sylvatica       1.00      0.50      0.67         2
#                Ginkgo_Biloba       0.50      1.00      0.67         1
#              Ilex_Aquifolium       1.00      0.75      0.86         4
#                 Ilex_Cornuta       1.00      1.00      1.00         1
#      Liquidambar_Styraciflua       1.00      1.00      1.00         1
#      Liriodendron_Tulipifera       0.00      0.00      0.00         0
#    Lithocarpus_Cleistocarpus       1.00      1.00      1.00         1
#           Lithocarpus_Edulis       1.00      1.00      1.00         2
#           Magnolia_Heptapeta       0.50      1.00      0.67         1
#         Magnolia_Salicifolia       1.00      1.00      1.00         2
#                  Morus_Nigra       1.00      1.00      1.00         3
#                Olea_Europaea       1.00      1.00      1.00         1
#                  Phildelphus       1.00      1.00      1.00         1
#            Populus_Adenopoda       0.50      1.00      0.67         1
#        Populus_Grandidentata       1.00      1.00      1.00         1
#                Populus_Nigra       1.00      1.00      1.00         3
#                 Prunus_Avium       1.00      1.00      1.00         2
#            Prunus_X_Shmittii       1.00      1.00      1.00         3
#        Pterocarya_Stenoptera       0.00      0.00      0.00         1
#               Quercus_Afares       1.00      1.00      1.00         1
#            Quercus_Agrifolia       1.00      1.00      1.00         1
#            Quercus_Alnifolia       1.00      1.00      1.00         2
#              Quercus_Brantii       1.00      1.00      1.00         1
#          Quercus_Canariensis       1.00      1.00      1.00         1
#        Quercus_Castaneifolia       0.50      1.00      0.67         1
#               Quercus_Cerris       0.00      0.00      0.00         1
#          Quercus_Chrysolepis       1.00      1.00      1.00         1
#            Quercus_Coccifera       1.00      1.00      1.00         1
#             Quercus_Coccinea       1.00      1.00      1.00         2
#          Quercus_Crassifolia       0.00      0.00      0.00         1
#            Quercus_Crassipes       1.00      1.00      1.00         3
#         Quercus_Dolicholepis       1.00      1.00      1.00         1
#        Quercus_Ellipsoidalis       1.00      1.00      1.00         2
#              Quercus_Greggii       1.00      1.00      1.00         2
#         Quercus_Hartwissiana       1.00      1.00      1.00         1
#                 Quercus_Ilex       1.00      1.00      1.00         1
#           Quercus_Imbricaria       1.00      1.00      1.00         1
#       Quercus_Infectoria_sub       1.00      1.00      1.00         1
#             Quercus_Kewensis       1.00      1.00      1.00         2
#
#                  avg / total       0.93      0.92      0.91        99

# %%
cm = sklearn.metrics.confusion_matrix(actual_index, best_guess_index)
plot_confusion_matrix(cm, metadata['one_hot_names'])
# Out:
# Confusion matrix, without normalization
